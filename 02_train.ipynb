# %% [markdown]
# <a href="https://colab.research.google.com/github/nahiim/colab/blob/main/02_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Training data
x = np.array([1, 2, 3, 4], dtype=float)
y = np.array([2, 4, 6, 8], dtype=float)

# Parameters
w = 0.0
b = 0.0
learning_rate = 0.01
epochs = 1000

n = len(x)

# Training loop
for epoch in range(epochs):
    # Make predictions
    y_pred = w * x + b

    # Compute loss (Mean Squared Error)
    loss = np.mean((y - y_pred) ** 2)

    # Compute gradients
    dw = (-2/n) * np.sum(x * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)

    # Update parameters
    w -= learning_rate * dw
    b -= learning_rate * db

    # Print progress every 100 epochs
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss:.4f}, w = {w:.4f}, b = {b:.4f}")

print(f"\nFinal model: y = {w:.2f}x + {b:.2f}")

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, w * x + b, color='red', label="Learned Line")
plt.legend()
plt.title("Linear Regression (from scratch)")
plt.grid(True)
plt.show()
# Out:
# Epoch 0: Loss = 30.0000, w = 0.3000, b = 0.1000
# Epoch 100: Loss = 0.0341, w = 1.8468, b = 0.4504
# Epoch 200: Loss = 0.0187, w = 1.8865, b = 0.3337
# Epoch 300: Loss = 0.0103, w = 1.9159, b = 0.2473
# Epoch 400: Loss = 0.0056, w = 1.9377, b = 0.1832
# Epoch 500: Loss = 0.0031, w = 1.9538, b = 0.1357
# Epoch 600: Loss = 0.0017, w = 1.9658, b = 0.1006
# Epoch 700: Loss = 0.0009, w = 1.9747, b = 0.0745
# Epoch 800: Loss = 0.0005, w = 1.9812, b = 0.0552
# Epoch 900: Loss = 0.0003, w = 1.9861, b = 0.0409
#
# Final model: y = 1.99x + 0.03
